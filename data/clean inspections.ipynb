# %% [markdown]
# Spring Cleaning: Inspection Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#read in the data to a pandas dataframe
df = pd.read_csv('Food_Inspections_raw.csv')
df.head()
# Out:
#    Inspection ID                      DBA Name                      AKA Name  \
# 0        1970470                        IYANZE                        IYANZE
# 1        1970465            KENYATTA'S DAYCARE            KENYATTA'S DAYCARE
# 2        1970461                       DOMINOS                       DOMINOS
# 3        1970431  ST JUDE EDUCATONAL INSTITUTE  ST JUDE EDUCATONAL INSTITUTE
# 4        1970429              FIRST SLICE, LLC                   FIRST SLICE
#
#    License #                    Facility Type             Risk  \
# 0  1909713.0                       Restaurant    Risk 1 (High)
# 1  2215571.0  Daycare Above and Under 2 Years    Risk 1 (High)
# 2  2464564.0                       Restaurant  Risk 2 (Medium)
# 3  2215504.0            Daycare (2 - 6 Years)    Risk 1 (High)
# 4  1620340.0                       Restaurant    Risk 1 (High)
#
#                   Address     City State      Zip Inspection Date  \
# 0   4623-4627 N BROADWAY   CHICAGO    IL  60640.0      10/28/2016
# 1         2334 E 75TH ST   CHICAGO    IL  60649.0      10/28/2016
# 2        1234 S CANAL ST   CHICAGO    IL  60607.0      10/28/2016
# 3         2219 E 79TH ST   CHICAGO    IL  60649.0      10/28/2016
# 4  4401 N RAVENSWOOD AVE   CHICAGO    IL  60640.0      10/28/2016
#
#            Inspection Type             Results  \
# 0     Short Form Complaint  Pass w/ Conditions
# 1                  License                Pass
# 2  Complaint Re-Inspection                Pass
# 3                  License                Pass
# 4                Complaint                Fail
#
#                                           Violations   Latitude  Longitude  \
# 0  34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOO...  41.966063 -87.657734
# 1  34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOO...  41.759085 -87.567448
# 2  35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTR...  41.866277 -87.639360
# 3  33. FOOD AND NON-FOOD CONTACT EQUIPMENT UTENSI...  41.751569 -87.570283
# 4  21. * CERTIFIED FOOD MANAGER ON SITE WHEN POTE...  41.961619 -87.673833
#
#                                   Location
# 0  (41.96606299325794, -87.65773412452839)
# 1  (41.75908547586528, -87.56744784945764)
# 2  (41.86627726994009, -87.63936045226205)
# 3  (41.75156886294461, -87.57028268677922)
# 4    (41.9616193448497, -87.6738326740156)

# %%
#break date into month, year, day
df['month'] = pd.DatetimeIndex(df['Inspection Date']).month
df['day'] = pd.DatetimeIndex(df['Inspection Date']).day
df['year'] = pd.DatetimeIndex(df['Inspection Date']).year

# %%
df.Risk.unique()
# Out:
# array(['Risk 1 (High)', 'Risk 2 (Medium)', 'Risk 3 (Low)', 'All', nan], dtype=object)

# %%
#recode risk as 1 (high), 2(med), 3(low)

for i in range(len(df)):
    if df.iloc[i,5] == "Risk 1 (High)":
        df.iloc[i,5] = 1
    if df.iloc[i,5] == "Risk 2 (Medium)":
        df.iloc[i,5] = 2
    if df.iloc[i,5] == "Risk 3 (Low)":
        df.iloc[i,5] = 3
    if df.iloc[i,5] == "All":
        df.iloc[i,5] = np.nan

# %%
df.Results.unique()
# Out:
# array(['Pass w/ Conditions', 'Pass', 'Fail', 'Not Ready', 'No Entry',
#        'Out of Business', 'Business Not Located'], dtype=object)

# %%
#recode results as 0 (pass), 1 (pass w conditions), 2 (fail), nan all missing data codes

for i in range(len(df)):
    if df.iloc[i,12] == "Pass":
        df.iloc[i,12] = 0
    if df.iloc[i,12] == "Pass w/ Conditions":
        df.iloc[i,12] = 1
    if df.iloc[i,12] == "Fail":
        df.iloc[i,12] = 2
    if df.iloc[i,12] in ('Not Ready', 'No Entry', 'Out of Business', 'Business Not Located'):
        df.iloc[i,12] = np.nan

# %%
df.head()
# Out:
#    Inspection ID                      DBA Name                      AKA Name  \
# 0        1970470                        IYANZE                        IYANZE
# 1        1970465            KENYATTA'S DAYCARE            KENYATTA'S DAYCARE
# 2        1970461                       DOMINOS                       DOMINOS
# 3        1970431  ST JUDE EDUCATONAL INSTITUTE  ST JUDE EDUCATONAL INSTITUTE
# 4        1970429              FIRST SLICE, LLC                   FIRST SLICE
#
#    License #                    Facility Type Risk                 Address  \
# 0  1909713.0                       Restaurant    1   4623-4627 N BROADWAY
# 1  2215571.0  Daycare Above and Under 2 Years    1         2334 E 75TH ST
# 2  2464564.0                       Restaurant    2        1234 S CANAL ST
# 3  2215504.0            Daycare (2 - 6 Years)    1         2219 E 79TH ST
# 4  1620340.0                       Restaurant    1  4401 N RAVENSWOOD AVE
#
#       City State      Zip Inspection Date          Inspection Type Results  \
# 0  CHICAGO    IL  60640.0      10/28/2016     Short Form Complaint       1
# 1  CHICAGO    IL  60649.0      10/28/2016                  License       0
# 2  CHICAGO    IL  60607.0      10/28/2016  Complaint Re-Inspection       0
# 3  CHICAGO    IL  60649.0      10/28/2016                  License       0
# 4  CHICAGO    IL  60640.0      10/28/2016                Complaint       2
#
#                                           Violations   Latitude  Longitude  \
# 0  34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOO...  41.966063 -87.657734
# 1  34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOO...  41.759085 -87.567448
# 2  35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTR...  41.866277 -87.639360
# 3  33. FOOD AND NON-FOOD CONTACT EQUIPMENT UTENSI...  41.751569 -87.570283
# 4  21. * CERTIFIED FOOD MANAGER ON SITE WHEN POTE...  41.961619 -87.673833
#
#                                   Location  month  day  year
# 0  (41.96606299325794, -87.65773412452839)     10   28  2016
# 1  (41.75908547586528, -87.56744784945764)     10   28  2016
# 2  (41.86627726994009, -87.63936045226205)     10   28  2016
# 3  (41.75156886294461, -87.57028268677922)     10   28  2016
# 4    (41.9616193448497, -87.6738326740156)     10   28  2016

# %%
#drop some columns we probably don't care about, can always get back later
df = df.drop(['Location','City','State','License #','AKA Name'], axis=1)

# %%
df.head()
# Out:
#    Inspection ID                      DBA Name  \
# 0        1970470                        IYANZE
# 1        1970465            KENYATTA'S DAYCARE
# 2        1970461                       DOMINOS
# 3        1970431  ST JUDE EDUCATONAL INSTITUTE
# 4        1970429              FIRST SLICE, LLC
#
#                      Facility Type Risk                 Address      Zip  \
# 0                       Restaurant    1   4623-4627 N BROADWAY   60640.0
# 1  Daycare Above and Under 2 Years    1         2334 E 75TH ST   60649.0
# 2                       Restaurant    2        1234 S CANAL ST   60607.0
# 3            Daycare (2 - 6 Years)    1         2219 E 79TH ST   60649.0
# 4                       Restaurant    1  4401 N RAVENSWOOD AVE   60640.0
#
#   Inspection Date          Inspection Type Results  \
# 0      10/28/2016     Short Form Complaint       1
# 1      10/28/2016                  License       0
# 2      10/28/2016  Complaint Re-Inspection       0
# 3      10/28/2016                  License       0
# 4      10/28/2016                Complaint       2
#
#                                           Violations   Latitude  Longitude  \
# 0  34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOO...  41.966063 -87.657734
# 1  34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOO...  41.759085 -87.567448
# 2  35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTR...  41.866277 -87.639360
# 3  33. FOOD AND NON-FOOD CONTACT EQUIPMENT UTENSI...  41.751569 -87.570283
# 4  21. * CERTIFIED FOOD MANAGER ON SITE WHEN POTE...  41.961619 -87.673833
#
#    month  day  year
# 0     10   28  2016
# 1     10   28  2016
# 2     10   28  2016
# 3     10   28  2016
# 4     10   28  2016

# %%
df.isnull().sum()
# Out:
# Inspection ID          0
# DBA Name               0
# Facility Type       4452
# Risk                  76
# Address                0
# Zip                  105
# Inspection Date        0
# Inspection Type        1
# Results            16282
# Violations         27249
# Latitude             479
# Longitude            479
# month                  0
# day                    0
# year                   0
# dtype: int64

# %%
#save the clean version

df.to_csv('Food_Inspections_Clean.csv', index=False)
